# %%
import pandas as pd

# %%
df = pd.read_csv("sarees.csv")

# %%
df.head()
# Out:
#    product_id       title                                product_description  \
# 0    19698082      Mitera  Women Cream-Coloured & Green Floral Silk Blend...
# 1    17314272  Saree mall   Mint Green & Gold Solid Linen Blend Taant Sarees
# 2    21425266     Satrani                   Woven Design Zari Banarasi Saree
# 3    18462146      KALINI                             Women Navy Blue Sarees
# 4    18465340   Silk Land  Beige & Orange Floral Printed Pure Cotton Jamd...
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.5              6         2599.0      68.0  "₹2,599.00"      INR
# 1     3.4             12         4799.0      73.0  "₹4,799.00"      INR
# 2     3.6            242         4699.0      74.0  "₹4,699.00"      INR
# 3     3.4             10         1599.0      60.0  "₹1,599.00"      INR
# 4     4.1             15         4125.0      70.0  "₹4,125.00"      INR
#
#                                               images  ...  \
# ...

# %%
df.tail()
# Out:
#     product_id            title  \
# 17    16287764       Saree mall
# 18    14975360           KALINI
# 19    19233030          Satrani
# 20    19823504         VAIRAGEE
# 21    19305196  MARGI DESIGNERS
#
#                                   product_description  rating  ratings_count  \
# 17                  Purple Silk Cotton Banarasi Saree     4.1            129
# 18          Yellow & Green Ethnic Motifs Fusion Saree     3.9           1194
# 19  Blue & Gold-Toned Woven Design Zari Silk Cotto...     0.0              0
# 20        Black Embellished Sequinned Celebrity Saree     4.2             19
# 21  Green & Gold-Toned Woven Design Zari Art Silk ...     0.0              0
#
#     initial_price  discount  final_price currency  \
# 17         4799.0      72.0  "₹1,343.00"      INR
# 18         2396.0      75.0    "₹599.00"      INR
# 19         4612.0      74.0  "₹1,199.00"      INR
# 20         9995.0      83.0  "₹1,699.00"      INR
# ...

# %%
df.shape
# Out:
# (22, 24)

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              22 non-null     int64
#  1   title                   22 non-null     str
#  2   product_description     22 non-null     str
#  3   rating                  22 non-null     float64
#  4   ratings_count           22 non-null     int64
#  5   initial_price           22 non-null     float64
#  6   discount                22 non-null     float64
#  7   final_price             22 non-null     str
#  8   currency                22 non-null     str
#  9   images                  22 non-null     str
#  10  delivery_options        22 non-null     str
#  11  product_details         22 non-null     str
#  12  breadcrumbs             22 non-null     str
#  13  product_specifications  22 non-null     str
#  14  amount_of_stars         22 non-null     str
# ...

# %%
df.describe()
# Out:
#          product_id     rating  ratings_count  initial_price   discount  \
# count  2.200000e+01  22.000000      22.000000      22.000000  22.000000
# mean   1.752238e+07   2.104545      92.136364    4582.272727  73.181818
# std    1.575838e+06   1.979052     262.262735    1722.660102   4.895444
# min    1.497536e+07   0.000000       0.000000    1599.000000  60.000000
# 25%    1.628775e+07   0.000000       0.000000    4099.000000  72.000000
# 50%    1.729235e+07   3.400000       8.000000    4349.000000  74.500000
# 75%    1.846454e+07   3.975000      17.250000    4799.000000  76.000000
# max    2.142527e+07   4.200000    1194.000000    9995.000000  83.000000
#
#        videos
# count     0.0
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %%
df.isnull().sum()
# Out:
# product_id                 0
# title                      0
# product_description        0
# rating                     0
# ratings_count              0
# initial_price              0
# discount                   0
# final_price                0
# currency                   0
# images                     0
# delivery_options           0
# product_details            0
# breadcrumbs                0
# product_specifications     0
# amount_of_stars            0
# what_customers_said       15
# seller_name                5
# sizes                      0
# videos                    22
# seller_information         5
# variations                 0
# best_offer                 0
# more_offers                0
# category                   0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (0, 24)

# %%
df = df.drop_duplicates()

# %%
high_rated = df[df["rating"] > 4]

high_rated.head()
# Out:
# Empty DataFrame
# Columns: [product_id, title, product_description, rating, ratings_count, initial_price, discount, final_price, currency, images, delivery_options, product_details, breadcrumbs, product_specifications, amount_of_stars, what_customers_said, seller_name, sizes, videos, seller_information, variations, best_offer, more_offers, category]
# Index: []
#
# [0 rows x 24 columns]

# %%
df[["title", "rating", "initial_price", "discount"]]
# Out:
# Empty DataFrame
# Columns: [title, rating, initial_price, discount]
# Index: []

# %%
df["discounted_amount"] = df["initial_price"] * (df["discount"] / 100)

# %%
df[["title", "initial_price", "discount", "discounted_amount"]].head()
# Out:
# Empty DataFrame
# Columns: [title, initial_price, discount, discounted_amount]
# Index: []

# %%
df.to_csv("cleaned_sarees.csv", index=False)
